# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from scipy import stats

# %%
data = pd.read_csv('F:\machine learning and deep learning\datasets\\flipkart_com-ecommerce_sample.csv')
data.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
data.columns
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'product_url', 'product_name',
#        'product_category_tree', 'pid', 'retail_price', 'discounted_price',
#        'image', 'is_FK_Advantage_product', 'description', 'product_rating',
#        'overall_rating', 'brand', 'product_specifications'],
#       dtype='object')

# %%
data.product_specifications.loc[0]
# Out:
# '{"product_specification"=>[{"key"=>"Number of Contents in Sales Package", "value"=>"Pack of 3"}, {"key"=>"Fabric", "value"=>"Cotton Lycra"}, {"key"=>"Type", "value"=>"Cycling Shorts"}, {"key"=>"Pattern", "value"=>"Solid"}, {"key"=>"Ideal For", "value"=>"Women\'s"}, {"value"=>"Gentle Machine Wash in Lukewarm Water, Do Not Bleach"}, {"key"=>"Style Code", "value"=>"ALTHT_3P_21"}, {"value"=>"3 shorts"}]}'

# %%
data.drop(['pid','crawl_timestamp','uniq_id','product_url','image','product_url','product_specifications','description'],axis=1,inplace=True)

# %%
data.head()
# Out:
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
#                                product_category_tree  retail_price  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...         999.0
# 1  ["Furniture >> Living Room Furniture >> Sofa B...       32157.0
# 2  ["Footwear >> Women's Footwear >> Ballerinas >...         999.0
# 3  ["Clothing >> Women's Clothing >> Lingerie, Sl...         699.0
# 4  ["Pet Supplies >> Grooming >> Skin & Coat Care...         220.0
#
#    discounted_price  is_FK_Advantage_product       product_rating  \
# 0             379.0                    False  No rating available
# 1           22646.0                    False  No rating available
# 2             499.0                    False  No rating available
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 8 columns):
# product_name               20000 non-null object
# product_category_tree      20000 non-null object
# retail_price               19922 non-null float64
# discounted_price           19922 non-null float64
# is_FK_Advantage_product    20000 non-null bool
# product_rating             20000 non-null object
# overall_rating             20000 non-null object
# brand                      14136 non-null object
# dtypes: bool(1), float64(2), object(5)
# memory usage: 1.1+ MB

# %%
data.head(10)
# Out:
#                                         product_name  \
# 0                Alisha Solid Women's Cycling Shorts
# 1                FabHomeDecor Fabric Double Sofa Bed
# 2                                         AW Bellies
# 3                Alisha Solid Women's Cycling Shorts
# 4              Sicons All Purpose Arnica Dog Shampoo
# 5  Eternal Gandhi Super Series Crystal Paper Weig...
# 6                Alisha Solid Women's Cycling Shorts
# 7                FabHomeDecor Fabric Double Sofa Bed
# 8  dilli bazaaar Bellies, Corporate Casuals, Casuals
# 9                Alisha Solid Women's Cycling Shorts
#
#                                product_category_tree  retail_price  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...         999.0
# 1  ["Furniture >> Living Room Furniture >> Sofa B...       32157.0
# 2  ["Footwear >> Women's Footwear >> Ballerinas >...         999.0
# 3  ["Clothing >> Women's Clothing >> Lingerie, Sl...         699.0
# ...

# %%
data.product_category_tree.loc[1]
# Out:
# '["Furniture >> Living Room Furniture >> Sofa Beds & Futons >> FabHomeDecor Fabric Double Sofa Bed (Finish Colo..."]'

# %%
data_master['sub-cat3'].iloc[1]
# Out:
# 'FabHomeDecor Fabric Double Sofa Bed (Finish Colo..."]'

# %%
d = {}
for i in data.index:
    a = data.product_category_tree[i].strip().split('>>')
    d[data.index[i]] = a

# %%
d
# Out:
# {0: ['["Clothing ',
#   " Women's Clothing ",
#   ' Lingerie, Sleep & Swimwear ',
#   ' Shorts ',
#   ' Alisha Shorts ',
#   ' Alisha Solid Women\'s Cycling Shorts"]'],
#  1: ['["Furniture ',
#   ' Living Room Furniture ',
#   ' Sofa Beds & Futons ',
#   ' FabHomeDecor Fabric Double Sofa Bed (Finish Colo..."]'],
#  2: ['["Footwear ', " Women's Footwear ", ' Ballerinas ', ' AW Bellies"]'],
#  3: ['["Clothing ',
#   " Women's Clothing ",
#   ' Lingerie, Sleep & Swimwear ',
#   ' Shorts ',
#   ' Alisha Shorts ',
#   ' Alisha Solid Women\'s Cycling Shorts"]'],
#  4: ['["Pet Supplies ',
#   ' Grooming ',
#   ' Skin & Coat Care ',
#   ' Shampoo ',
#   ' Sicons All Purpose Arnica Dog Shampoo (500 ml)"]'],
#  5: ['["Eternal Gandhi Super Series Crystal Paper Weight..."]'],
#  6: ['["Clothing ',
#   " Women's Clothing ",
#   ' Lingerie, Sleep & Swimwear ',
#   ' Shorts ',
#   ' Alisha Shorts ',
#   ' Alisha Solid Women\'s Cycling Shorts"]'],
#  7: ['["Furniture ',
# ...

# %%
a = []
for i in d.values():
    if len(i) < 8:
        for j in range(8-len(i)):
            i.append('')
    a.append(len(i))

# %%
b = pd.DataFrame(d).T#,index=['category','sub-cat1','sub-cat2','sub-cat3','sub-cat4','sub-cat5','sub-cat6']).fillna(0).T

# %%
b.head(10)
# Out:
#                                                    0                        1  \
# 0                                        ["Clothing         Women's Clothing
# 1                                       ["Furniture    Living Room Furniture
# 2                                        ["Footwear         Women's Footwear
# 3                                        ["Clothing         Women's Clothing
# 4                                    ["Pet Supplies                 Grooming
# 5  ["Eternal Gandhi Super Series Crystal Paper We...
# 6                                        ["Clothing         Women's Clothing
# 7                                       ["Furniture    Living Room Furniture
# 8                                        ["Footwear         Women's Footwear
# 9                                        ["Clothing         Women's Clothing
#
#                               2  \
# 0   Lingerie, Sleep & Swimwear
# 1           Sofa Beds & Futons
# 2                   Ballerinas
# ...

# %%
b.columns = ['category','sub-cat1','sub-cat2','sub-cat3','sub-cat4','sub-cat5','sub-cat6','sub-cat7']

# %%
data_master = data.merge(b, left_index=True, right_index=True)

# %%
data_master.head()
# Out:
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
#                                product_category_tree  retail_price  \
# 0  ["Clothing >> Women's Clothing >> Lingerie, Sl...         999.0
# 1  ["Furniture >> Living Room Furniture >> Sofa B...       32157.0
# 2  ["Footwear >> Women's Footwear >> Ballerinas >...         999.0
# 3  ["Clothing >> Women's Clothing >> Lingerie, Sl...         699.0
# 4  ["Pet Supplies >> Grooming >> Skin & Coat Care...         220.0
#
#    discounted_price  is_FK_Advantage_product       product_rating  \
# 0             379.0                    False  No rating available
# 1           22646.0                    False  No rating available
# 2             499.0                    False  No rating available
# ...

# %%
data_master.drop('product_category_tree',axis=1,inplace=True)

# %%
data_master.head()
# Out:
#                             product_name  retail_price  discounted_price  \
# 0    Alisha Solid Women's Cycling Shorts         999.0             379.0
# 1    FabHomeDecor Fabric Double Sofa Bed       32157.0           22646.0
# 2                             AW Bellies         999.0             499.0
# 3    Alisha Solid Women's Cycling Shorts         699.0             267.0
# 4  Sicons All Purpose Arnica Dog Shampoo         220.0             210.0
#
#    is_FK_Advantage_product       product_rating       overall_rating  \
# 0                    False  No rating available  No rating available
# 1                    False  No rating available  No rating available
# 2                    False  No rating available  No rating available
# 3                    False  No rating available  No rating available
# 4                    False  No rating available  No rating available
#
#           brand         category                 sub-cat1  \
# ...

# %%
def clean(x):
    return x.replace('"[','').replace(']"','').replace('"','').strip()

# %%
data_master['category'] = data_master['category'].apply(clean)
data_master['sub-cat1'] = data_master['sub-cat1'].apply(clean)
data_master['sub-cat2'] = data_master['sub-cat2'].apply(clean)
data_master['sub-cat3'] = data_master['sub-cat3'].apply(clean)
data_master['sub-cat4'] = data_master['sub-cat4'].apply(clean)
data_master['sub-cat5'] = data_master['sub-cat5'].apply(clean)
data_master['sub-cat6'] = data_master['sub-cat6'].apply(clean)
data_master['sub-cat7'] = data_master['sub-cat7'].apply(clean)

# %%
data_master.head()
# Out:
#                             product_name  retail_price  discounted_price  \
# 0    Alisha Solid Women's Cycling Shorts         999.0             379.0
# 1    FabHomeDecor Fabric Double Sofa Bed       32157.0           22646.0
# 2                             AW Bellies         999.0             499.0
# 3    Alisha Solid Women's Cycling Shorts         699.0             267.0
# 4  Sicons All Purpose Arnica Dog Shampoo         220.0             210.0
#
#    is_FK_Advantage_product       product_rating       overall_rating  \
# 0                    False  No rating available  No rating available
# 1                    False  No rating available  No rating available
# 2                    False  No rating available  No rating available
# 3                    False  No rating available  No rating available
# 4                    False  No rating available  No rating available
#
#           brand      category               sub-cat1  \
# 0        Alisha      Clothing       Women's Clothing
# ...

# %%
data_master.category.loc[0]
# Out:
# '"Clothing'

# %%
data_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
# product_name               20000 non-null object
# retail_price               19922 non-null float64
# discounted_price           19922 non-null float64
# is_FK_Advantage_product    20000 non-null bool
# product_rating             20000 non-null object
# overall_rating             20000 non-null object
# brand                      14136 non-null object
# category                   20000 non-null object
# sub-cat1                   20000 non-null object
# sub-cat2                   20000 non-null object
# sub-cat3                   20000 non-null object
# sub-cat4                   20000 non-null object
# sub-cat5                   20000 non-null object
# sub-cat6                   20000 non-null object
# sub-cat7                   20000 non-null object
# dtypes: bool(1), float64(2), object(12)
# memory usage: 2.2+ MB

# %%
data_master[['product_rating','overall_rating']].apply(lambda x : x.replace('No rating available',np.nan)).isnull().sum()/data_master.shape[0]
# Out:
# product_rating    0.90755
# overall_rating    0.90755
# dtype: float64

# %%
data_master.drop(['product_rating','overall_rating'],axis=1,inplace=True)
