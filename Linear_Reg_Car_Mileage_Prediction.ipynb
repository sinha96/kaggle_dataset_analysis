# %%
# Numerical libraries
import numpy as np   
# Import Linear Regression machine learning library
from sklearn.linear_model import LinearRegression
# to handle data in form of rows and columns 
import pandas as pd    
# importing ploting libraries
import matplotlib.pyplot as plt   
#importing seaborn for statistical plots
import seaborn as sns
# To enable plotting graphs in Jupyter notebook
# %matplotlib inline 
import statsmodels.formula.api as smf

# %%
# reading the CSV file into pandas dataframe
mpg_df = pd.read_csv("car-mpg.csv")

# %%
mpg_df.shape
# Out:
# (398, 10)

# %%
mpg_df.head()
# Out:
#     mpg  cyl   disp   hp    wt   acc  yr  origin  car_type  \
# 0  18.0    8  307.0  130  3504  12.0  70       1         0
# 1  15.0    8  350.0  165  3693  11.5  70       1         0
# 2  18.0    8  318.0  150  3436  11.0  70       1         0
# 3  16.0    8  304.0  150  3433  12.0  70       1         0
# 4  17.0    8  302.0  140  3449  10.5  70       1         0
#
#                     car_name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %%
m1=smf.ols('mpg~wt',mpg_df).fit()

# %%
m1.params
# Out:
# Intercept    46.317364
# wt           -0.007677
# dtype: float64

# %%
ypred=m1.predict(mpg_df['wt'])
m1.rsquared
# Out:
# 0.6917929800341576

# %%
rmse=np.sqrt(np.mean((mpg_df['mpg']-ypred)**2))
rmse
# Out:
# 4.3336981591509565

# %%
X=mpg_df[['wt']]
Y=mpg_df['mpg']

# %%
m2=LinearRegression()
m2.fit(X,Y)
ypred2=m2.predict(X)
rmse2=np.sqrt(np.mean((mpg_df['mpg']-ypred2)**2))
rmse2
# Out:
# 4.3336981591509565

# %%
m2.score(X,Y)
# Out:
# 0.6917929800341575

# %%
m2.intercept_
# Out:
# 46.31736442026563

# %%
m2.coef_
# Out:
# array([-0.00767661])

# %%
# Check top few records to get a feel of the data structure
mpg_df.shape
# Out:
# (398, 10)

# %%
# drop the car name column as it is useless for the model
mpg_df = mpg_df.drop('car_name', axis=1)

# %%
mpg_df.describe().transpose()
# Out:
#           count         mean         std     min       25%     50%       75%  \
# mpg       398.0    23.514573    7.815984     9.0    17.500    23.0    29.000
# cyl       398.0     5.454774    1.701004     3.0     4.000     4.0     8.000
# disp      398.0   193.425879  104.269838    68.0   104.250   148.5   262.000
# wt        398.0  2970.424623  846.841774  1613.0  2223.750  2803.5  3608.000
# acc       398.0    15.568090    2.757689     8.0    13.825    15.5    17.175
# yr        398.0    76.010050    3.697627    70.0    73.000    76.0    79.000
# origin    398.0     1.572864    0.802055     1.0     1.000     1.0     2.000
# car_type  398.0     0.530151    0.499718     0.0     0.000     1.0     1.000
#
#              max
# mpg         46.6
# cyl          8.0
# disp       455.0
# wt        5140.0
# acc         24.8
# yr          82.0
# origin       3.0
# car_type     1.0

# %%
# Note:  HP column is missing the describe output. That indicates something is not right with that column

# %%
#Check if the hp column contains anything other than digits 
# run the "isdigit() check on 'hp' column of the mpg_df dataframe. Result will be True or False for every row
# capture the result in temp dataframe and dow a frequency count using value_counts()
# There are six records with non digit values in 'hp' column
temp = pd.DataFrame(mpg_df.hp.str.isdigit())
temp[temp['hp'] == False]
mpg_df = mpg_df.replace('?', np.nan)
mpg_df[mpg_df.isnull().any(axis=1)]
mpg_df = mpg_df.fillna(mpg_df.median())

# %%
temp[temp['hp'] == False]
# Out:
#         hp
# 32   False
# 126  False
# 330  False
# 336  False
# 354  False
# 374  False

# %%
# On inspecting records number 32, 126 etc, we find "?" in the columns. Replace them with "nan"
#Replace them with nan and remove the records from the data frame that have "nan"
mpg_df = mpg_df.replace('?', np.nan)

# %%
#Let us see if we can get those records with nan
mpg_df[mpg_df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [mpg, cyl, disp, hp, wt, acc, yr, origin, car_type]
# Index: []

# %%
#of the 398 rows 6 have NAN in the hp column. We will drop those 6 rows. Not a good idea under all situations
#note: HP is missing becauses of the non-numeric values in the column. 
#mpg_df = mpg_df.dropna()

# %%
# replace the missing values in 'hp' with median value of 'hp' :Note, we do not need to specify the column names
# every column's missing value is replaced with that column's median respectively
mpg_df = mpg_df.fillna(mpg_df.median())

# %%
mpg_df['hp'].dtype
# Out:
# dtype('O')

# %%
# The "hp" column was treated as an object when data was loaded into the dataframe as it contained "?"

mpg_df['hp']=mpg_df['hp'].astype('float64')
mpg_df.describe().transpose()
# Out:
#           count         mean         std     min       25%     50%       75%  \
# mpg       398.0    23.514573    7.815984     9.0    17.500    23.0    29.000
# cyl       398.0     5.454774    1.701004     3.0     4.000     4.0     8.000
# disp      398.0   193.425879  104.269838    68.0   104.250   148.5   262.000
# hp        398.0   104.304020   38.222625    46.0    76.000    93.5   125.000
# wt        398.0  2970.424623  846.841774  1613.0  2223.750  2803.5  3608.000
# acc       398.0    15.568090    2.757689     8.0    13.825    15.5    17.175
# yr        398.0    76.010050    3.697627    70.0    73.000    76.0    79.000
# origin    398.0     1.572864    0.802055     1.0     1.000     1.0     2.000
# car_type  398.0     0.530151    0.499718     0.0     0.000     1.0     1.000
#
#              max
# mpg         46.6
# cyl          8.0
# disp       455.0
# hp         230.0
# wt        5140.0
# acc         24.8
# yr          82.0
# origin       3.0
# car_type     1.0

# %%
#let us look at each attribute and understand it's distribution
mpg_df.describe().transpose()
# Out:
#           count         mean         std     min       25%     50%       75%  \
# mpg       398.0    23.514573    7.815984     9.0    17.500    23.0    29.000
# cyl       398.0     5.454774    1.701004     3.0     4.000     4.0     8.000
# disp      398.0   193.425879  104.269838    68.0   104.250   148.5   262.000
# hp        398.0   104.304020   38.222625    46.0    76.000    93.5   125.000
# wt        398.0  2970.424623  846.841774  1613.0  2223.750  2803.5  3608.000
# acc       398.0    15.568090    2.757689     8.0    13.825    15.5    17.175
# yr        398.0    76.010050    3.697627    70.0    73.000    76.0    79.000
# origin    398.0     1.572864    0.802055     1.0     1.000     1.0     2.000
# car_type  398.0     0.530151    0.499718     0.0     0.000     1.0     1.000
#
#              max
# mpg         46.6
# cyl          8.0
# disp       455.0
# hp         230.0
# wt        5140.0
# acc         24.8
# yr          82.0
# origin       3.0
# car_type     1.0

# %%
# Study the distribution of the data in each column. Columns which do not have random distributions may not be good 
# for model as random processes cannot be modeled
mpg_df.hp.hist()

# %%
# Let us visually inspect the central values and the spread
sns.boxplot(mpg_df.hp, color = "yellow", orient = "h")

# %%
# Let us do a correlation analysis among the different dimensions and also each dimension with the dependent dimension
# This is done using scatter matrix function which creates a dashboard reflecting useful information about the dimensions
# The result can be stored as a .png file and opened in say, paint to get a larger view 

mpg_df_attr = mpg_df.iloc[:,0:7]

axes = pd.plotting.scatter_matrix(mpg_df_attr)
plt.tight_layout()
plt.savefig('mpg_pairpanel.png')

# %%
sns.pairplot(mpg_df,diag_kind='kde')
# Out:
# /usr/local/anaconda/python3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
mpg_df.corr()
# Out:
#                mpg       cyl      disp        hp        wt       acc  \
# mpg       1.000000 -0.775396 -0.804203 -0.773453 -0.831741  0.420289
# cyl      -0.775396  1.000000  0.950721  0.841284  0.896017 -0.505419
# disp     -0.804203  0.950721  1.000000  0.895778  0.932824 -0.543684
# hp       -0.773453  0.841284  0.895778  1.000000  0.862442 -0.686590
# wt       -0.831741  0.896017  0.932824  0.862442  1.000000 -0.417457
# acc       0.420289 -0.505419 -0.543684 -0.686590 -0.417457  1.000000
# yr        0.579267 -0.348746 -0.370164 -0.413733 -0.306564  0.288137
# origin    0.563450 -0.562543 -0.609409 -0.452096 -0.581024  0.205873
# car_type  0.759207 -0.912577 -0.855141 -0.701399 -0.815445  0.385187
#
#                 yr    origin  car_type
# mpg       0.579267  0.563450  0.759207
# cyl      -0.348746 -0.562543 -0.912577
# disp     -0.370164 -0.609409 -0.855141
# hp       -0.413733 -0.452096 -0.701399
# wt       -0.306564 -0.581024 -0.815445
# acc       0.288137  0.205873  0.385187
# yr        1.000000  0.180662  0.305194
# origin    0.180662  1.000000  0.572691
# car_type  0.305194  0.572691  1.000000

# %%
# Copy all the predictor variables into X dataframe. Since 'mpg' is dependent variable drop it
X = mpg_df.drop(['mpg','yr','acc','disp','origin'], axis=1)

# Copy the 'mpg' column alone into the y dataframe. This is the dependent variable
y = mpg_df['mpg']

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
X.head()
# Out:
#    cyl   disp     hp    wt  car_type
# 0    8  307.0  130.0  3504         0
# 1    8  350.0  165.0  3693         0
# 2    8  318.0  150.0  3436         0
# 3    8  304.0  150.0  3433         0
# 4    8  302.0  140.0  3449         0

# %%
#Let us break the X and y dataframes into training set and test set. For this we will use
#Sklearn package's data splitting function which is based on random function

from sklearn.model_selection import train_test_split

# %%
# Split X and y into training and test set in 75:25 ratio

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=2)

# %%
X_train.head()
# Out:
#      cyl   disp     hp    wt  car_type
# 112    4  122.0   85.0  2310         1
# 283    6  232.0   90.0  3265         0
# 379    4   98.0   70.0  2125         1
# 306    6  173.0  115.0  2595         0
# 343    4   79.0   58.0  1755         1

# %%
X_test.shape
# Out:
# (120, 5)

# %%
y_train.shape
# Out:
# (278,)

# %%
y_test.shape
# Out:
# (120,)

# %%
# invoke the LinearRegression function and find the bestfit model on training data
regression_model = LinearRegression()
regression_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_pred=regression_model.predict(X_test)

# %%
plt.plot(y_test,y_pred,'*')

# %%
np.corrcoef(y_test,y_pred)
# Out:
# array([[1.        , 0.85615313],
#        [0.85615313, 1.        ]])

# %%
0.85616894*0.85616894
# Out:
# 0.7330252538207236

# %%
1-(np.sum((y_test-y_pred)**2)/np.sum((y_test-np.mean(y_test))**2))
# Out:
# 0.7323729278538389

# %%
regression_model.score(X_test,y_test)
# Out:
# 0.732344180536566

# %%
# Let us explore the coefficients for each of the independent attributes
for idx, col_name in enumerate(X_train.columns):
    print("The coefficient for {} is {}".format(col_name, regression_model.coef_[idx]))
# Out:
# The coefficient for cyl is 1.6666141622801638
# The coefficient for disp is 0.0011399481576857898
# The coefficient for hp is -0.0746531829208343
# The coefficient for wt is -0.004427353933737483
# The coefficient for car_type is 7.211851063494733

# %%
X_train.columns
# Out:
# Index(['cyl', 'disp', 'hp', 'wt', 'car_type'], dtype='object')

# %%
regression_model.coef_[2]
# Out:
# -0.0746531829208343

# %%
regression_model.intercept_
# Out:
# 31.271962945597394

# %%
31.272+1.667*6+0.00113*198-0.0746*95-0.00442*2833
# Out:
# 21.888880000000004

# %%
np.sqrt(np.mean((y_test-y_pred)**2))
# Out:
# 3.9757946424150905

# %%
# Let us check the intercept for the model

intercept = regression_model.intercept_

print("The intercept for our model is {}".format(intercept))
# Out:
# The intercept for our model is 31.271962945597394

# %%
# Model score - R2 or coeff of determinant
regression_model.score(X_test, y_test)
# Out:
# 0.7323729278538389

# %%
# So the model explains 73.2% of the variability in Y using X

# %%
# Let us check the sum of squared errors by predicting value of y for test cases and 
# subtracting from the actual y for the test cases

rmse = np.sqrt(np.mean((regression_model.predict(X_test)-y_test)**2))
rmse
# Out:
# 3.975581128471538

# %%
y_pred=regression_model.predict(X_test)

# %%
y_pred
# Out:
# array([ 8.09249823, 29.22354683, 30.73316849, 25.62589876, 28.01273174,
#         8.53258485,  9.05412118, 15.21878934, 14.52169511, 17.76049899,
#        25.64864086, 28.49747676, 33.35028693, 20.60109595, 31.54766754,
#        27.94307129, 18.87313301, 28.09665129, 32.97127256, 18.5570142 ,
#        29.75857543, 18.96416169, 29.39392227, 27.76765891, 11.29899166,
#        18.24660755, 26.95094833, 21.01399617, 29.15449984, 18.76669462,
#        32.66188754, 29.64643968, 23.05607792, 29.74199225,  9.96526894,
#        31.41024005, 18.58309639, 32.52905156,  9.59311737, 31.05299256,
#        17.89854875, 21.15894254, 21.61211863, 28.51524245, 29.24147302,
#        31.45145442, 18.45186225, 12.17447494, 32.06163791, 27.74483579,
#        30.24575016, 23.04092585, 26.77694998, 26.74716253, 28.01121374,
#        13.50066734, 30.32101518, 20.3826788 , 14.99641741, 28.56754763,
#        31.60522314, 27.85422761, 30.97946889, 20.67338049, 16.025454  ,
#        30.14289918, 23.70055238, 18.72533912, 13.3310597 , 31.65068534,
#        19.91032373, 31.88054871, 15.63496061, 29.79797722, 29.4068711 ,
#        18.40552989, 18.71435567, 15.30251667, 17.51009568, 28.47405716,
#        31.21100912, 29.32015788, 18.55433699, 26.3488194 , 22.11753969,
#        30.09609684, 32.16921387, 27.05535725, 18.82698659, 15.81342295,
#        25.56523404, 17.4961994 , 30.12090918, 26.78258136, 20.92988729,
#        30.11048221, 17.21159992, 14.66377226, 31.38385544, 31.45702172,
#        18.22392025, 32.4547607 , 29.26110165, 29.30475744, 23.32059953,
#        32.25012827, 19.32166394, 31.45135862, 28.60142592, 16.94971565,
#        17.67854924, 24.93363512, 24.3286341 , 19.35265542, 16.43130923,
#        20.43928351, 21.03224026, 29.76360254, 28.54046747, 16.57577323])

# %%
plt.plot(y_test,y_pred,'*')

# %%
np.corrcoef(y_test,y_pred)
# Out:
# array([[1.        , 0.85616894],
#        [0.85616894, 1.        ]])

# %%
0.85616894**2
# Out:
# 0.7330252538207236

# %%
# so there is avg of 4.0 (roundoff) mpg difference from real mpg on an avg

# %%
# predict mileage (mpg) for a set of attributes not in the training or test set
y_pred = regression_model.predict(X_test)

# %%
# Since this is regression, plot the predicted y value vs actual y values for the test data
# A good model's prediction will be close to actual leading to high R and R2 values
plt.scatter(y_test, y_pred)

# %%
type(y_test)
# Out:
# pandas.core.series.Series

# %%
len(y_test)
# Out:
# 120

# %%
len(y_pred)
# Out:
# 120

# %%
np.corrcoef(y_test,y_pred)
# Out:
# array([[1.        , 0.85616894],
#        [0.85616894, 1.        ]])

# %%
0.86056386*0.86056386
# Out:
# 0.7405701571380995

# %%
sns.regplot(mpg_df.wt, mpg_df.mpg, order=1,scatter_kws={'color':'r'})
# Out:
# /usr/local/anaconda/python3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
model=LinearRegression()
x=X[['wt']]
model.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
ypred=model.predict(x)

# %%
mpg_df.plot.scatter(x='wt',y='mpg')
plt.plot(x,ypred,c='red')

# %%
X_train.head()
# Out:
#      cyl   disp     hp    wt  car_type
# 112    4  122.0   85.0  2310         1
# 283    6  232.0   90.0  3265         0
# 379    4   98.0   70.0  2125         1
# 306    6  173.0  115.0  2595         0
# 343    4   79.0   58.0  1755         1

# %%
new_df=pd.concat([X_train,y_train],axis=1)
new_df.head()
# Out:
#      cyl     hp    wt  car_type   mpg
# 112    4   85.0  2310         1  19.0
# 283    6   90.0  3265         0  20.2
# 379    4   70.0  2125         1  36.0
# 306    6  115.0  2595         0  28.8
# 343    4   58.0  1755         1  39.1

# %%
#Implementation using OLS
model2=smf.ols('mpg~cyl+hp+wt+car_type',new_df).fit()

# %%
model2.params
# Out:
# Intercept    31.120036
# cyl           1.697774
# hp           -0.073997
# wt           -0.004381
# car_type      7.205794
# dtype: float64

# %%
y2_pred=model2.params[0]+model2.params[1]*X_test['cyl'].iloc[0]+model2.params[2]*X_test['disp'].iloc[0]+model2.params[3]*X_test['hp'].iloc[0]+model2.params[4]*X_test['wt'].iloc[0]+model2.params[5]*X_test['car_type'].iloc[0]
y2_pred
# Out:
# 8.092498228998313

# %%
X_test.shape
# Out:
# (120, 5)

# %%
y2_pred=[]

# %%
for i in np.arange(120):
    y2_pred.append(model2.params[0]+model2.params[1]*X_test['cyl'].iloc[i]
                   +model2.params[2]*X_test['disp'].iloc[i]
                   +model2.params[3]*X_test['hp'].iloc[i]
                   +model2.params[4]*X_test['wt'].iloc[i]
                   +model2.params[5]*X_test['car_type'].iloc[i])

# %%
new_df.corr()
# Out:
#                cyl      disp        hp        wt  car_type       mpg
# cyl       1.000000  0.950857  0.849223  0.898081 -0.910292 -0.780902
# disp      0.950857  1.000000  0.901980  0.941860 -0.850773 -0.810514
# hp        0.849223  0.901980  1.000000  0.874420 -0.700496 -0.782715
# wt        0.898081  0.941860  0.874420  1.000000 -0.806065 -0.827661
# car_type -0.910292 -0.850773 -0.700496 -0.806065  1.000000  0.757998
# mpg      -0.780902 -0.810514 -0.782715 -0.827661  0.757998  1.000000

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.734
# Model:                            OLS   Adj. R-squared:                  0.729
# Method:                 Least Squares   F-statistic:                     150.2
# Date:                Wed, 06 Feb 2019   Prob (F-statistic):           4.47e-76
# Time:                        10:21:22   Log-Likelihood:                -783.12
# No. Observations:                 278   AIC:                             1578.
# Df Residuals:                     272   BIC:                             1600.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     31.2720      3.099     10.090      0.000      25.170      37.374
# cyl            1.6666      0.607      2.745      0.006       0.471       2.862
# disp           0.0011      0.011      0.104      0.917      -0.020       0.023
# hp            -0.0747      0.016     -4.624      0.000      -0.106      -0.043
# wt            -0.0044      0.001     -5.045      0.000      -0.006      -0.003
# car_type       7.2119      1.268      5.685      0.000       4.715       9.709
# ==============================================================================
# Omnibus:                       30.869   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.912
# Skew:                           0.692   Prob(JB):                     6.51e-11
# Kurtosis:                       4.460   Cond. No.                     4.22e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.22e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    mpg   R-squared:                       0.734
# Model:                            OLS   Adj. R-squared:                  0.730
# Method:                 Least Squares   F-statistic:                     188.4
# Date:                Wed, 06 Feb 2019   Prob (F-statistic):           3.07e-77
# Time:                        10:53:32   Log-Likelihood:                -783.13
# No. Observations:                 278   AIC:                             1576.
# Df Residuals:                     273   BIC:                             1594.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     31.1200      2.727     11.411      0.000      25.751      36.489
# cyl            1.6978      0.527      3.223      0.001       0.661       2.735
# hp            -0.0740      0.015     -4.990      0.000      -0.103      -0.045
# wt            -0.0044      0.001     -5.806      0.000      -0.006      -0.003
# car_type       7.2058      1.265      5.697      0.000       4.716       9.696
# ==============================================================================
# Omnibus:                       31.116   Durbin-Watson:                   1.959
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.439
# Skew:                           0.696   Prob(JB):                     5.00e-11
# Kurtosis:                       4.469   Cond. No.                     3.83e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.83e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
