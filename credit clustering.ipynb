# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy import stats
from sklearn.cluster import KMeans,AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
data = pd.read_csv(r'F:\machine learning and deep learning\datasets\datasets-for-isrl\credit.csv')
data.head()
# Out:
#    Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 0           1   14.891   3606     283      2   34         11    Male      No
# 1           2  106.025   6645     483      3   82         15  Female     Yes
# 2           3  104.593   7075     514      4   71         11    Male      No
# 3           4  148.924   9504     681      3   36         11  Female      No
# 4           5   55.882   4897     357      2   68         16    Male      No
#
#   Married  Ethnicity  Balance
# 0     Yes  Caucasian      333
# 1     Yes      Asian      903
# 2      No      Asian      580
# 3      No      Asian      964
# 4     Yes  Caucasian      331

# %%
data.Ethnicity.unique()
# Out:
# array(['Caucasian', 'Asian', 'African American'], dtype=object)

# %%
data.Education.unique()
# Out:
# array([11, 15, 16, 10, 12,  9, 13, 19, 14,  7, 17,  8,  5, 20, 18,  6],
#       dtype=int64)

# %%
data.drop([data.columns[0],'Gender','Married','Ethnicity'],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
# Income       400 non-null float64
# Limit        400 non-null int64
# Rating       400 non-null int64
# Cards        400 non-null int64
# Age          400 non-null int64
# Education    400 non-null int64
# Student      400 non-null object
# Balance      400 non-null int64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 25.1+ KB

# %%
data.head()
# Out:
#     Income  Limit  Rating  Cards  Age  Education Student  Balance
# 0   14.891   3606     283      2   34         11      No      333
# 1  106.025   6645     483      3   82         15     Yes      903
# 2  104.593   7075     514      4   71         11      No      580
# 3  148.924   9504     681      3   36         11      No      964
# 4   55.882   4897     357      2   68         16      No      331

# %%
sns.distplot(data.Limit)

# %%
data.Student,student_name = pd.factorize(data.Student)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
# Income       400 non-null float64
# Limit        400 non-null int64
# Rating       400 non-null int64
# Cards        400 non-null int64
# Age          400 non-null int64
# Education    400 non-null int64
# Student      400 non-null int64
# Balance      400 non-null int64
# dtypes: float64(1), int64(7)
# memory usage: 25.1 KB

# %%
data.Student = data.Student.astype('category')
data.Education = data.Education.astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 8 columns):
# Income       400 non-null float64
# Limit        400 non-null int64
# Rating       400 non-null int64
# Cards        400 non-null int64
# Age          400 non-null int64
# Education    400 non-null category
# Student      400 non-null category
# Balance      400 non-null int64
# dtypes: category(2), float64(1), int64(5)
# memory usage: 20.5 KB

# %%
import seaborn as sns
sns.pairplot(data,diag_kind='kde');

# %%
sc = StandardScaler()
X = sc.fit_transform(data.drop(['Education','Student'],axis=1))
# Out:
# f:\great_learnings\lib\site-packages\sklearn\preprocessing\data.py:645: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# f:\great_learnings\lib\site-packages\sklearn\base.py:464: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
sns.pairplot(pd.DataFrame(X));

# %%
pca = PCA()
x_pca = pca.fit_transform(X)

# %%
clusterer = KMeans(n_clusters=2)

# %%
data['group'] = clusterer.fit_predict(x_pca)

# %%
data.head()
# Out:
#     Income  Limit  Rating  Cards  Age Education Student  Balance  group
# 0   14.891   3606     283      2   34        11       0      333      0
# 1  106.025   6645     483      3   82        15       1      903      1
# 2  104.593   7075     514      4   71        11       0      580      1
# 3  148.924   9504     681      3   36        11       0      964      1
# 4   55.882   4897     357      2   68        16       0      331      0

# %%
sns.pairplot(data,hue='group');
# Out:
# f:\great_learnings\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# f:\great_learnings\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
from sklearn.metrics import silhouette_score
from yellowbrick.cluster import SilhouetteVisualizer
ab = data
error = []
for i in range(2,11):
    mdl = KMeans(n_clusters=i,random_state=42)
    a = mdl.fit_predict(data)
    error.append(mdl.inertia_)
    ab['k_'+str(i)] = a
    # Instantiate the clustering model and visualizer
    print('silhoutte coef for {} clusters is {}'.format(i,silhouette_score(data, ab['k_'+str(i)])))
    visualizer = SilhouetteVisualizer(mdl)
    fig = plt.figure(figsize=(10,10))
    visualizer.fit(data) # Fit the training data to the visualizer
    visualizer.poof() # Draw/show/poof the data
# Out:
# silhoutte coef for 2 clusters is 0.5317098274227544
# silhoutte coef for 3 clusters is 0.5462289948543753
# silhoutte coef for 4 clusters is 0.539372823720878
# silhoutte coef for 5 clusters is 0.5286941320598653
# silhoutte coef for 6 clusters is 0.4912402258957376
# silhoutte coef for 7 clusters is 0.48788836989204015
# silhoutte coef for 8 clusters is 0.4763401173738087
# silhoutte coef for 9 clusters is 0.46084892052165793
# silhoutte coef for 10 clusters is 0.4556951578851918

# %%
data.head()
# Out:
#     Income  Limit  Rating  Cards  Age Education Student  Balance  group  k_2  \
# 0   14.891   3606     283      2   34        11       0      333      0    1
# 1  106.025   6645     483      3   82        15       1      903      1    0
# 2  104.593   7075     514      4   71        11       0      580      1    0
# 3  148.924   9504     681      3   36        11       0      964      1    0
# 4   55.882   4897     357      2   68        16       0      331      0    1
#
#    k_3  k_4  k_5  k_6  k_7  k_8  k_9  k_10
# 0    1    2    1    1    0    7    7     3
# 1    0    0    2    0    1    5    8     1
# 2    0    0    2    5    6    5    8     1
# 3    2    3    0    2    5    6    5     2
# 4    0    1    4    4    3    2    1     4

# %%
data.columns
# Out:
# Index(['Income', 'Limit', 'Rating', 'Cards', 'Age', 'Education', 'Student',
#        'Balance', 'group', 'k_2', 'k_3', 'k_4', 'k_5', 'k_6', 'k_7', 'k_8',
#        'k_9', 'k_10'],
#       dtype='object')

# %%
sns.pairplot(data.iloc[:,0:11].drop(['group','k_2'],axis=1),hue='k_3');
# Out:
# f:\great_learnings\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# f:\great_learnings\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
df = data.iloc[:,0:11].drop(['group','k_2'],axis=1)

# %%
fig = plt.figure(figsize=(10,20))
df.boxplot(by='k_3');

# %%
df
# Out:
#       Income  Limit  Rating  Cards  Age Education Student  Balance  k_3
# 0     14.891   3606     283      2   34        11       0      333    1
# 1    106.025   6645     483      3   82        15       1      903    0
# 2    104.593   7075     514      4   71        11       0      580    0
# 3    148.924   9504     681      3   36        11       0      964    2
# 4     55.882   4897     357      2   68        16       0      331    0
# 5     80.180   8047     569      4   77        10       0     1151    2
# 6     20.996   3388     259      2   37        12       0      203    1
# 7     71.408   7114     512      2   87         9       0      872    0
# 8     15.125   3300     266      5   66        13       0      279    1
# 9     71.061   6819     491      3   41        19       1     1350    0
# 10    63.095   8117     589      4   30        14       0     1407    2
# 11    15.045   1311     138      3   64        16       0        0    1
# 12    80.616   5308     394      1   57         7       0      204    0
# 13    43.682   6922     511      1   49         9       0     1081    0
# 14    19.144   3291     269      2   75        13       0      148    1
# 15    20.089   2525     200      3   57        15       0        0    1
# 16    53.598   3714     286      3   73        17       0        0    1
# 17    36.496   4378     339      3   69        15       0      368    0
# 18    49.570   6384     448      1   28         9       0      891    0
# 19    42.079   6626     479      2   44         9       0     1048    0
# 20    17.700   2860     235      4   63        16       0       89    1
# 21    37.348   6378     458      1   72        17       0      968    0
# 22    20.103   2631     213      3   61        10       0        0    1
# 23    64.027   5179     398      5   48         8       0      411    0
# 24    10.742   1757     156      3   57        15       0        0    1
# 25    14.090   4323     326      5   25        16       0      671    0
# 26    42.471   3625     289      6   44        12       1      654    1
# 27    32.793   4534     333      2   44        16       0      467    0
# 28   186.634  13414     949      2   41        14       0     1809    2
# 29    26.813   5611     411      4   55        16       0      915    0
# ..       ...    ...     ...    ...  ...       ...     ...      ...  ...
# 370   35.610   6135     466      4   40        12       0      992    0
# 371   39.116   2150     173      4   75        15       0        0    1
# 372   19.782   3782     293      2   46        16       1      840    1
# 373   55.412   5354     383      2   37        16       1     1003    0
# 374   29.400   4840     368      3   76        18       0      588    0
# 375   20.974   5673     413      5   44        16       0     1000    0
# 376   87.625   7167     515      2   46        10       0      767    0
# 377   28.144   1567     142      3   51        10       0        0    1
# 378   19.349   4941     366      1   33        19       0      717    0
# 379   53.308   2860     214      1   84        10       0        0    1
# 380  115.123   7760     538      3   83        14       0      661    2
# 381  101.788   8029     574      2   84        11       0      849    2
# 382   24.824   5495     409      1   33         9       1     1352    0
# 383   14.292   3274     282      9   64         9       0      382    1
# 384   20.088   1870     180      3   76        16       0        0    1
# 385   26.400   5640     398      3   58        15       0      905    0
# 386   19.253   3683     287      4   57        10       0      371    1
# 387   16.529   1357     126      3   62         9       0        0    1
# 388   37.878   6827     482      2   80        13       0     1129    0
# 389   83.948   7100     503      2   44        18       0      806    0
# 390  135.118  10578     747      3   81        15       0     1393    2
# 391   73.327   6555     472      2   43        15       0      721    0
# 392   25.974   2308     196      2   24        10       0        0    1
# 393   17.316   1335     138      2   65        13       0        0    1
# 394   49.794   5758     410      4   40         8       0      734    0
# 395   12.096   4100     307      3   32        13       0      560    0
# 396   13.364   3838     296      5   65        17       0      480    1
# 397   57.872   4171     321      5   67        12       0      138    0
# 398   37.728   2525     192      1   44        13       0        0    1
# 399   18.701   5524     415      5   64         7       0      966    0
#
# [400 rows x 9 columns]

# %%
group_dic = {0:'Customer with medium limit',1:'Customer with low limit',2:'Customer with high limit'}

# %%
df.k_3 = df.k_3.map(group_dic)

# %%
df.head()
# Out:
#     Income  Limit  Rating  Cards  Age Education Student  Balance  \
# 0   14.891   3606     283      2   34        11       0      333
# 1  106.025   6645     483      3   82        15       1      903
# 2  104.593   7075     514      4   71        11       0      580
# 3  148.924   9504     681      3   36        11       0      964
# 4   55.882   4897     357      2   68        16       0      331
#
#                           k_3
# 0     Customer with low limit
# 1  Customer with medium limit
# 2  Customer with medium limit
# 3    Customer with high limit
# 4  Customer with medium limit

# %%
fig = plt.figure(figsize=(10,7))
plt.plot(range(2,11),error,marker='o');

# %%
df2 = pd.concat([data.iloc[:,0:8],data['k_4'],data['k_5']],axis=1)

# %%
error[2]-error[3]
# Out:
# 91253915.4739691

# %%
error[3]-error[4]
# Out:
# 33396549.5912935

# %%
error[4]-error[5]
# Out:
# 28075463.42303036

# %%
error[5]-error[6]
# Out:
# 20872258.892106473

# %%
sns.pairplot(df2.drop('k_4',axis=1),hue='k_5',diag_kind='kde');
# Out:
# f:\great_learnings\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# f:\great_learnings\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
sns.pairplot(pd.DataFrame(x_pca));
